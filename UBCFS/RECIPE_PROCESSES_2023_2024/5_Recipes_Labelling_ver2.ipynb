# %% [markdown]
# # Labelling Recipes Stage
# **Sharon Marfatia**

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifty_cutoff = 191.12
# is the overall baseline supposed to be the GHG_baseline?
overall_baseline = 382.25

GHG_baseline = 382.25
nitrogen_baseline = 3.86
water_baseline = 1248.19
land_baseline = 0.93

# %%
# CHANGE THIS AS NEEDED:
# restaurant_name = "OK23-24"
# restaurant_name = "Gather23-24"
restaurant_name = "Totem23-24"

# %%
def create_ghg_label(label):
    # determine the GHG label based on the given label value and predefined cutoffs
    if label > overall_baseline:
        # if the label value is > than overall baseline, assign "Red" label
        return "Red"
    elif (label <= overall_baseline) & (label > fifty_cutoff):
        # if the label value is between overall baseline and fifty_cutoff, assign "Yellow" label
        return "Yellow"
    elif label <= fifty_cutoff:
        # if the label value is less than or equal to the fifty_cutoff, assign "Green" label
        return "Green"

# %%
def create_results_all_factors(df):
    # create a Combined Label based on different factors for each row in the DataFrame
    df["Combined Label"] = ""

    # add another parameter: n so that change the number of factors instead of multiplying by 3

    def calculate_all_factors(ghg, nitrogen, water, land):
        # calculate the combined label value based on the given factors
        weighted_ghg = ghg / (4 * GHG_baseline)
        weighted_nitrogen = nitrogen / (4 * nitrogen_baseline)
        weighted_water = water / (4 * water_baseline)

        # most recently added
        weighted_land = land / (4 * land_baseline)

        return weighted_ghg + weighted_nitrogen + weighted_water + weighted_land


    for ind, row in df.iterrows():
        # iterate over each row in the DataFrame and calculate the combined label
        label = calculate_all_factors(row["GHG Emission (g) / 100g"], row["N lost (g) / 100g"],
                                      row["Stress-Weighted Water Use (L) / 100g"],
                                      row['Land Use (m^2) / 100g'])

        if label <= 0.5:
            # if the label value is less than or equal to 0.5, assign "Green" label
            df.loc[ind, "Combined Label"] = "Green"
        elif label >= 1:
            # if the label value is greater than or equal to 1, assign "Red" label
            df.loc[ind, "Combined Label"] = "Red"
        elif (label > 0.5) or (label < 1):
            # if the label value is between 0.5 and 1, assign "Yellow" label
            df.loc[ind, "Combined Label"] = "Yellow"
    return df

# %%
def add_menu_names(df, dict):
    # add menu names to the DataFrame based on a dictionary
    df["Displayed Name"] = ""
    menu_name = list(dict.keys())
    menu_ID = list(dict.values())
    for ind, row in df.iterrows():
        searchID = row["ProdId"]
        if searchID in menu_ID:
            # if the product ID is found in the menu_ID list, retrieve the corresponding name
            position = menu_ID.index(searchID)
            name = menu_name[position]
            df.loc[ind, "Displayed Name"] = name
        else:
            continue
    name_col = df.pop("Displayed Name")
    df.insert(0, "Displayed Name", name_col)
    df = df.dropna(subset=["Displayed Name"])

    df_temp = df["Displayed Name"].str.split("|", expand=True)
    df["Category"] = df_temp[0]
    df["Displayed Name"] = df_temp[1]
    name_col2 = df.pop("Category")
    df.insert(0, "Category", name_col2)
    # returns the modified DataFrame with the added "Category" and "Displayed Name" columns
    return df

# %%
def create_final_counts(df):
    # create final counts of GHG and combined labels from DataFrame

    # count the occurrences of GHG Only labels
    ghg_red = df["GHG Only Label"].value_counts()["Red"]
    ghg_yellow = df["GHG Only Label"].value_counts()["Yellow"]
    ghg_green = df["GHG Only Label"].value_counts()["Green"]
    # count the occurrences of Combined labels
    all_red = df["Combined Label"].value_counts()["Red"]
    all_yellow = df["Combined Label"].value_counts()["Yellow"]
    all_green = df["Combined Label"].value_counts()["Green"]
    print(all_red, all_yellow, all_green)
    # create a dictionary to store the label counts
    data = {"GHG Label Counts": [ghg_red, ghg_yellow, ghg_green],
            "Combined Label Counts": [all_red, all_yellow, all_green]}
    # create a DataFrame from the label counts data and return it
    results = pd.DataFrame(data, index=["Red", "Yellow", "Green"])
    return results

# %%
def create_visualizations(df):
    df.reset_index(inplace=True)
    df = df.rename(columns={"index": "Color"})
    sns.set_theme(style="darkgrid")
    palette = {"Green": "tab:green", "Red": "tab:red", "Yellow": "tab:orange", "Sum": "tab:blue"}
    fig, axes = plt.subplots(1, 2, figsize=(7, 4), sharex=False, sharey=True)
    fig.suptitle("Emission Label Counts")
    ax1 = sns.barplot(data=df, x=df["Color"], y=df["GHG Label Counts"], ax=axes[0], palette=palette)
    ax1.set_title("GHG Emission Label")
    ax1.set_ylabel("Counts")
    ax1.set_xlabel("")
    ax2 = sns.barplot(data=df, x=df["Color"], y=df["Combined Label Counts"], ax=axes[1], palette=palette)
    ax2.set_title("Combined Emissions Label")
    ax2.set_ylabel("")
    ax2.set_xlabel("")
    fig.title = "Color Comparison"
    ax1.set_title = "GHG Emission Label Counts"
    ax2.set_title = "Combined Emissions Label Counts"
    ax2.set_ylabel = ""
    for ax in [ax1, ax2]:
        for i in ax.containers:
            ax.bar_label(i, )
    plt.tight_layout()
    plt.savefig("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Summary_fig.png")
    plt.show()

# %%
def create_category_true(df):
    # create category columns for True values in the DataFrame

    # create empty columns for each category
    df["RED"] = ""
    df["YELLOW"] = ""
    df["GREEN"] = ""
    # iterate over each row in the DataFrame
    for ind, row in df.iterrows():
        # Check the value of the Combined Label column and assign "TRUE" to the corresponding category column
        if row["Combined Label"] == "Red":
            df.loc[ind, "RED"] = "TRUE"
        if row["Combined Label"] == "Yellow":
            df.loc[ind, "YELLOW"] = "TRUE"
        if row["Combined Label"] == "Green":
            df.loc[ind, "GREEN"] = "TRUE"
    # adds category columns for True values based on the Combined Label column
    return df

# %%
products = pd.read_csv('C:/Users/smvan/CFFS-S23/CFFS-22-23/data/preprocessed/Products_List.csv')

# %%
final = products.copy()
final
# Out:
#        ProdId             Description          SalesGroup  Weight (g)  \
# 0     R-47209    5 spice powder|spice      FT HOMESKILLET     453.592
# 1     R-55408              ADD|Cheese               FEAST      14.000
# 2     R-63588            ADD|CHICKEN         FT GRAB & GO     113.400
# 3     R-63593   ADD|Chicken Strip Dip           FT SIDES       45.000
# 4     R-65790      ADD|Chili|TAILGATE            SPECIALS      65.000
# ...       ...                     ...                 ...         ...
# 1627  R-38902        YAKISOBA NOODLES  FT GRILL FREATURES     226.796
# 1628  R-64311  YERBA MATE UNSWEETENED        FT BEVERAGES       1.000
# 1629  R-40585        YOSO - BLUEBERRY        FT GRAB & GO       1.000
# 1630  R-40512       YOSO - STRAWBERRY        FT GRAB & GO    1000.000
# 1631  R-40532          YOSO - VANILLA        FT GRAB & GO    1000.000
#
#       GHG Emission (g)  N lost (g)  Land Use (m^2)  \
# 0          4250.293118    3.061746       14.061352
# 1           124.745602    1.306200        0.146440
# 2           692.861065   17.522310        1.886223
# 3            23.842866    0.191065        0.004900
# 4           959.766350    7.770525        2.968200
# ...                ...         ...             ...
# 1627        173.306983    1.617434        0.000000
# 1628          0.000000    0.000000        0.000000
# 1629          0.489000    0.002370        0.000780
# 1630          0.000000    0.000000        0.000000
# 1631          0.000000    0.000000        0.000000
#
#       Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                          11.29                          99.93
# 1                          21.83                        1126.48
# 2                          55.56                          50.17
# 3                           0.63                          33.17
# 4                          41.24                        1560.07
# ...                          ...                            ...
# 1627                       37.33                        1174.01
# 1628                        0.00                           0.00
# 1629                        0.00                           0.01
# 1630                        1.00                           1.00
# 1631                        1.00                           1.00
#
#       GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                      937.03               0.68
# 1                      891.04               9.33
# 2                      610.99              15.45
# 3                       52.98               0.42
# 4                     1476.56              11.95
# ...                       ...                ...
# 1627                    76.42               0.71
# 1628                     0.00               0.00
# 1629                    48.90               0.24
# 1630                     0.00               0.00
# 1631                     0.00               0.00
#
#       Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                  2.49                                 22.03
# 1                                155.93                               8046.29
# 2                                 48.99                                 44.24
# 3                                  1.40                                 73.71
# 4                                 63.45                               2400.11
# ...                                 ...                                   ...
# 1627                              16.46                                517.65
# 1628                               0.00                                  0.00
# 1629                               0.00                                  1.00
# 1630                               0.10                                  0.10
# 1631                               0.10                                  0.10
#
#       Land Use (m^2) / 100g
# 0                      3.10
# 1                      1.05
# 2                      1.66
# 3                      0.01
# 4                      4.57
# ...                     ...
# 1627                   0.00
# 1628                   0.00
# 1629                   0.08
# 1630                   0.00
# 1631                   0.00
#
# [1632 rows x 14 columns]

# %%
final["GHG Only Label"] = final["GHG Emission (g) / 100g"].apply(lambda x: create_ghg_label(x))
final
# Out:
#        ProdId             Description          SalesGroup  Weight (g)  \
# 0     R-47209    5 spice powder|spice      FT HOMESKILLET     453.592
# 1     R-55408              ADD|Cheese               FEAST      14.000
# 2     R-63588            ADD|CHICKEN         FT GRAB & GO     113.400
# 3     R-63593   ADD|Chicken Strip Dip           FT SIDES       45.000
# 4     R-65790      ADD|Chili|TAILGATE            SPECIALS      65.000
# ...       ...                     ...                 ...         ...
# 1627  R-38902        YAKISOBA NOODLES  FT GRILL FREATURES     226.796
# 1628  R-64311  YERBA MATE UNSWEETENED        FT BEVERAGES       1.000
# 1629  R-40585        YOSO - BLUEBERRY        FT GRAB & GO       1.000
# 1630  R-40512       YOSO - STRAWBERRY        FT GRAB & GO    1000.000
# 1631  R-40532          YOSO - VANILLA        FT GRAB & GO    1000.000
#
#       GHG Emission (g)  N lost (g)  Land Use (m^2)  \
# 0          4250.293118    3.061746       14.061352
# 1           124.745602    1.306200        0.146440
# 2           692.861065   17.522310        1.886223
# 3            23.842866    0.191065        0.004900
# 4           959.766350    7.770525        2.968200
# ...                ...         ...             ...
# 1627        173.306983    1.617434        0.000000
# 1628          0.000000    0.000000        0.000000
# 1629          0.489000    0.002370        0.000780
# 1630          0.000000    0.000000        0.000000
# 1631          0.000000    0.000000        0.000000
#
#       Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                          11.29                          99.93
# 1                          21.83                        1126.48
# 2                          55.56                          50.17
# 3                           0.63                          33.17
# 4                          41.24                        1560.07
# ...                          ...                            ...
# 1627                       37.33                        1174.01
# 1628                        0.00                           0.00
# 1629                        0.00                           0.01
# 1630                        1.00                           1.00
# 1631                        1.00                           1.00
#
#       GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                      937.03               0.68
# 1                      891.04               9.33
# 2                      610.99              15.45
# 3                       52.98               0.42
# 4                     1476.56              11.95
# ...                       ...                ...
# 1627                    76.42               0.71
# 1628                     0.00               0.00
# 1629                    48.90               0.24
# 1630                     0.00               0.00
# 1631                     0.00               0.00
#
#       Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                  2.49                                 22.03
# 1                                155.93                               8046.29
# 2                                 48.99                                 44.24
# 3                                  1.40                                 73.71
# 4                                 63.45                               2400.11
# ...                                 ...                                   ...
# 1627                              16.46                                517.65
# 1628                               0.00                                  0.00
# 1629                               0.00                                  1.00
# 1630                               0.10                                  0.10
# 1631                               0.10                                  0.10
#
#       Land Use (m^2) / 100g GHG Only Label
# 0                      3.10            Red
# 1                      1.05            Red
# 2                      1.66            Red
# 3                      0.01          Green
# 4                      4.57            Red
# ...                     ...            ...
# 1627                   0.00          Green
# 1628                   0.00          Green
# 1629                   0.08          Green
# 1630                   0.00          Green
# 1631                   0.00          Green
#
# [1632 rows x 15 columns]

# %%
final = create_results_all_factors(final)
final
# Out:
#        ProdId             Description          SalesGroup  Weight (g)  \
# 0     R-47209    5 spice powder|spice      FT HOMESKILLET     453.592
# 1     R-55408              ADD|Cheese               FEAST      14.000
# 2     R-63588            ADD|CHICKEN         FT GRAB & GO     113.400
# 3     R-63593   ADD|Chicken Strip Dip           FT SIDES       45.000
# 4     R-65790      ADD|Chili|TAILGATE            SPECIALS      65.000
# ...       ...                     ...                 ...         ...
# 1627  R-38902        YAKISOBA NOODLES  FT GRILL FREATURES     226.796
# 1628  R-64311  YERBA MATE UNSWEETENED        FT BEVERAGES       1.000
# 1629  R-40585        YOSO - BLUEBERRY        FT GRAB & GO       1.000
# 1630  R-40512       YOSO - STRAWBERRY        FT GRAB & GO    1000.000
# 1631  R-40532          YOSO - VANILLA        FT GRAB & GO    1000.000
#
#       GHG Emission (g)  N lost (g)  Land Use (m^2)  \
# 0          4250.293118    3.061746       14.061352
# 1           124.745602    1.306200        0.146440
# 2           692.861065   17.522310        1.886223
# 3            23.842866    0.191065        0.004900
# 4           959.766350    7.770525        2.968200
# ...                ...         ...             ...
# 1627        173.306983    1.617434        0.000000
# 1628          0.000000    0.000000        0.000000
# 1629          0.489000    0.002370        0.000780
# 1630          0.000000    0.000000        0.000000
# 1631          0.000000    0.000000        0.000000
#
#       Freshwater Withdrawals (L)  Stress-Weighted Water Use (L)  \
# 0                          11.29                          99.93
# 1                          21.83                        1126.48
# 2                          55.56                          50.17
# 3                           0.63                          33.17
# 4                          41.24                        1560.07
# ...                          ...                            ...
# 1627                       37.33                        1174.01
# 1628                        0.00                           0.00
# 1629                        0.00                           0.01
# 1630                        1.00                           1.00
# 1631                        1.00                           1.00
#
#       GHG Emission (g) / 100g  N lost (g) / 100g  \
# 0                      937.03               0.68
# 1                      891.04               9.33
# 2                      610.99              15.45
# 3                       52.98               0.42
# 4                     1476.56              11.95
# ...                       ...                ...
# 1627                    76.42               0.71
# 1628                     0.00               0.00
# 1629                    48.90               0.24
# 1630                     0.00               0.00
# 1631                     0.00               0.00
#
#       Freshwater Withdrawals (L) / 100g  Stress-Weighted Water Use (L) / 100g  \
# 0                                  2.49                                 22.03
# 1                                155.93                               8046.29
# 2                                 48.99                                 44.24
# 3                                  1.40                                 73.71
# 4                                 63.45                               2400.11
# ...                                 ...                                   ...
# 1627                              16.46                                517.65
# 1628                               0.00                                  0.00
# 1629                               0.00                                  1.00
# 1630                               0.10                                  0.10
# 1631                               0.10                                  0.10
#
#       Land Use (m^2) / 100g GHG Only Label Combined Label
# 0                      3.10            Red            Red
# 1                      1.05            Red            Red
# 2                      1.66            Red            Red
# 3                      0.01          Green          Green
# 4                      4.57            Red            Red
# ...                     ...            ...            ...
# 1627                   0.00          Green          Green
# 1628                   0.00          Green          Green
# 1629                   0.08          Green          Green
# 1630                   0.00          Green          Green
# 1631                   0.00          Green          Green
#
# [1632 rows x 16 columns]

# %%
final.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+".csv", 
             index=False)
final.to_excel("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+".xlsx", 
               sheet_name="Labels", index=False)

# %%
# CHANGE THE NAME AS NEEDED AS PER THE RESTAURANT:

OK_list = final.set_index('Description')['ProdId'].to_dict()
OK_list
# Out:
# {'5 spice powder|spice': 'R-47209',
#  'ADD|Cheese': 'R-55408',
#  'ADD|CHICKEN ': 'R-63588',
#  'ADD|Chicken Strip Dip': 'R-63593',
#  'ADD|Chili|TAILGATE': 'R-65790',
#  'ADD|Crackers': 'R-22896',
#  'ADD|Fried Egg': 'R-62187',
#  'ADD|Guacamole ': 'R-56809',
#  'ADD|Havarti|1 SLICE': 'R-62363',
#  'ADD|Kimchi': 'R-56468',
#  'ADD|Perogy|SIDE (4pc)': 'R-62301',
#  'ADD|Poached Egg': 'R-44853',
#  'ADD|Prawns': 'R-61856',
#  'ADD|SHRIMP': 'R-64375',
#  'ADD|Tailgate cheddar': 'R-65788',
#  'ALF|Pasta|Cauliflower Cheese': 'R-61659',
#  'ALF|Pasta|Chicken Alfredo': 'R-56505',
#  'ALF|Pasta|Chorizo Penne': 'R-51303',
#  'AQlCreme Caramel|PTN': 'R-65631',
#  'AQlDynamite Power Plant Bowl': 'R-65622',
#  'AQlMiso Glazed Salmon Bowl': 'R-65620',
#  'ASSORTED DANISH': 'R-64338',
#  'BAKE| GF VEGAN RASPBRY CHOC': 'R-65918',
#  'BAKE|Bagel Asst': 'R-52751',
#  'BAKE|BAKED PRETZEL': 'R-64357',
#  'BAKE|Cake|Ponderosa': 'R-19583',
#  'BAKE|Cinnamon Bun': 'R-52747',
#  'BAKE|Croissant|Almond': 'R-52742',
#  'BAKE|Croissant|Cheese': 'R-52743',
#  'BAKE|Croissant|Chocolate': 'R-52744',
#  'BAKE|Croissant|Multigrain': 'R-34270',
#  'BAKE|Croissant|Plain': 'R-52741',
#  'BAKE|Croissant|Spinach Pepper ': 'R-52793',
#  'BAKE|Danish|Almond Pear|MC': 'R-52750',
#  'BAKE|Danish|Supreme Asst': 'R-52749',
#  'BAKE|Loaf|Sweet Asst': 'R-21282',
#  'BAKE|Muffin|Asst': 'R-46225',
#  'BAKE|Scone|Asst': 'R-20398',
#  'BAKE|Scone|Cran & Blueberry|MC': 'R-47788',
#  'BAKED LAYS ORIGINAL': 'R-64236',
#  'BATCH|Chili Garlic Tofu|SIDE': 'R-56911',
#  'BATCH|Crispy Fried Tofu|side': 'R-56908',
#  'BATCH|Fire Roasted Salsa': 'R-56807',
#  'BATCH|Roasted Carrots AR|Side': 'R-57000',
#  'Beef Donair': 'R-56286',
#  'BENTO PORK DUMPLINGS': 'R-63589',
#  'BERKIPOPIMAINIHALIBUT': 'R-70967',
#  'BERKIPOPIVEGETARIANIMUSHTART': 'R-71200',
#  'BERRIES & QUINOA SALAD W/ OW S': 'R-38748',
#  'BEV\\SMARTWATER  1L ANTIOX': 'R-64760',
#  'BEV\\Water|Smart 1L Alkaline': 'R-64761',
#  'BEV|Coffee|12 oz': 'R-23583',
#  'BEV|Coffee|16 oz': 'R-23584',
#  'BEV|Coffee|Ceramic|12oz': 'R-23635',
#  'BEV|Coffee|Ethical Bean Promo': 'R-67307',
#  'BEV|Cold Brew|Two Bears|Black': 'R-52932',
#  'BEV|Cold Brew|Two Bears|Latte': 'R-53123',
#  'BEV|Cold Brew|Two Bears|Mocha': 'R-52930',
#  'BEV|Core Power Elite Chocolate': 'R-63859',
#  'BEV|Core Power Shake Banana': 'R-64237',
#  'BEV|Core Power|Chocolate': 'R-52790',
#  'BEV|Core Power|StrawberryBanan': 'R-48633',
#  'BEV|Core Power|Vanilla': 'R-52791',
#  'BEV|Fruit Water|Black Cherry': 'R-46380',
#  'BEV|Fruit Water|Peach Mango': 'R-46381',
#  'BEV|Happy Planet|Blackberry': 'R-38309',
#  'BEV|Happy Planet|Coconut Pinea': 'R-39281',
#  "BEV|Happy Planet|Extreme 'C'": 'R-58276',
#  'BEV|Happy Planet|Extreme Energ': 'R-38607',
#  'BEV|Happy Planet|Extreme Green': 'R-37537',
#  'BEV|Happy Planet|Mango Passion': 'R-38603',
#  'BEV|Happy Planet|Raspberry': 'R-37833',
#  'BEV|Hot Apple Cider|Package': 'R-22296',
#  'BEV|Hot Chocolate|Package': 'R-49312',
#  'BEV|Ice Tea|Gold Peak|Lemon': 'R-34518',
#  'BEV|Ice Tea|Gold Peak|Raspberr': 'R-38376',
#  'BEV|Ice Tea|Gold Peak|Unsweet': 'R-38190',
#  'BEV|Ice Tea|Nestea|Green|500ml': 'R-38593',
#  'BEV|Ice Tea|Nestea|Half|500ml': 'R-37560',
#  'BEV|Ice Tea|Nestea|Lemon|500ml': 'R-38151',
#  'BEV|Ice Tea|Nestea|Zero|500ml': 'R-38903',
#  'BEV|Ice Tea|Steaz|Asst': 'R-22871',
#  'BEV|Ice Tea|Steaz|Blueberry ': 'R-38887',
#  'BEV|Ice Tea|Steaz|Coconut': 'R-40501',
#  'BEV|Ice Tea|Steaz|Goji ': 'R-53025',
#  'BEV|Ice Tea|Steaz|Half & Half': 'R-58247',
#  'BEV|Ice Tea|Steaz|Lemon Unswee': 'R-39229',
#  'BEV|Ice Tea|Steaz|Peach': 'R-39812',
#  'BEV|Ice Tea|Steaz|Raspberry': 'R-38655',
#  "BEV|Iced Coffee|Tim's|Double": 'R-56320',
#  'BEV|Juice|Bulk 12oz': 'R-22765',
#  'BEV|Juice|Bulk 12oz|To Go': 'R-22863',
#  'BEV|Juice|MM|Apple|355ml': 'R-38339',
#  'BEV|Juice|MM|Cranberry 355ml': 'R-38204',
#  'BEV|Juice|MM|Five Alive|355ml': 'R-38822',
#  'BEV|Juice|MM|Grapefruit|355ml': 'R-38197',
#  'BEV|Juice|MM|Lemonade|355ml': 'R-38340',
#  'BEV|Juice|MM|Orange|355ml': 'R-38338',
#  'BEV|Juice|Simply Apple': 'R-38148',
#  'BEV|Juice|Simply|Lemonade': 'R-38141',
#  'BEV|Juice|Simply|Orange': 'R-38142',
#  'BEV|Juice|Simply|Peach 340ml': 'R-41896',
#  'BEV|KARMA - APPLE': 'R-64374',
#  'BEV|KARMA - PEACH': 'R-64372',
#  'BEV|KARMA - PEAR': 'R-64373',
#  'BEV|KARMA |CHERRY': 'R-64764',
#  'BEV|KARMA|BERRY': 'R-64763',
#  'BEV|Kombucha|Asst': 'R-32115',
#  'BEV|Kombucha|Cherry': 'R-40511',
#  'BEV|Kombucha|Pear': 'R-40514',
#  'BEV|Kombucha|Traditional': 'R-40513',
#  'BEV|Milk-To-Go|1%': 'R-53132',
#  'BEV|Milk-To-Go|1%.': 'R-40503',
#  'BEV|Milk-To-Go|2%': 'R-42483',
#  'BEV|Milk-To-Go|Asst': 'R-22301',
#  'BEV|Milk-To-Go|Banana': 'R-40904',
#  "BEV|Milk-To-Go|Chillin' Choco": 'R-40504',
#  'BEV|Milk-To-Go|Choc Low Sugar': 'R-52289',
#  'BEV|Milk-To-Go|Chocolate': 'R-52811',
#  'BEV|Milk-To-Go|Chocolate.': 'R-40534',
#  'BEV|Milk-To-Go|Iced Coffee': 'R-40499',
#  'BEV|Milk|237ml|2%': 'R-22299',
#  'BEV|Milk|237ml|Chocolate': 'R-20389',
#  'BEV|Milk|473 ml|2%': 'R-38174',
#  'BEV|Milk|473 ml|Chocolate': 'R-49813',
#  'BEV|Milk|Almond Breeze|Choco': 'R-61299',
#  'BEV|Milk|Almond Breeze|Vanilla': 'R-61300',
#  'BEV|Milk|Almond|Asst': 'R-22289',
#  'BEV|Milk|Almond|Chocolate': 'R-55558',
#  'BEV|Milk|Almond|Silk': 'R-53986',
#  'BEV|Milk|Bulk|Chocolate 12oz': 'R-13192',
#  'BEV|Milk|Bulk|White 12oz': 'R-13191',
#  'BEV|Milk|Oat|Chocolate': 'R-55606',
#  'BEV|Milk|Oat|Original': 'R-55584',
#  'BEV|Milk|Rice|Asst': 'R-22965',
#  'BEV|Milk|Rice|Chocolate': 'R-40493',
#  'BEV|Milk|Soy|Original': 'R-21285',
#  'BEV|OASIS - APPLE': 'R-64856',
#  'BEV|OASIS - ORANGE': 'R-64855',
#  'BEV|Pop|1 liter|Asst': 'R-25329',
#  'BEV|Pop|Bulk 12oz': 'R-22772',
#  'BEV|Pop|Bulk 12oz|To Go': 'R-22862',
#  'BEV|POP|COKE BLKBERRY DIET': 'R-63534',
#  'BEV|POP|COKE DIET VANILLA  EX': 'R-63533',
#  'BEV|Pop|Coke Diet|500ml': 'R-39125',
#  'BEV|POP|COKE ZERO  CHERRY ': 'R-63532',
#  'BEV|Pop|Coke Zero|500ml': 'R-38897',
#  'BEV|Pop|Coke Zero|Can 355ml': 'R-54354',
#  'BEV|Pop|Fresca|500ml': 'R-52748',
#  'BEV|Powerade|Fruit Punch|710ml': 'R-47465',
#  'BEV|Powerade|Grape Zero|710ml': 'R-53024',
#  'BEV|Powerade|Grape|710ml': 'R-48464',
#  'BEV|Powerade|Mix Berry|710ml': 'R-47461',
#  'BEV|TEA COLD CHAI LATTE': 'R-63647',
#  'BEV|TEA COLD TWO BEARS MATCHA': 'R-63648',
#  'BEV|Tea|Hot|Asst': 'R-23632',
#  'BEV|Tribe Cider|Blackberry': 'R-55619',
#  'BEV|Tribe Cider|Peach': 'R-55618',
#  'BEV|Tribe Cider|Tropical Blend': 'R-55608',
#  'BEV|VITAMIN WATER SQUEEZE ZERO': 'R-64295',
#  'BEV|Vitasoy|Asst': 'R-22974',
#  'BEV|Vitasoy|Beige': 'R-41334',
#  'BEV|Vitasoy|Black Currant': 'R-40492',
#  'BEV|Vitasoy|Black Soy': 'R-40913',
#  'BEV|Vitasoy|Ceylon': 'R-40537',
#  'BEV|Vitasoy|Chocolate': 'R-40535',
#  'BEV|Vitasoy|Chrysanthem|500ml': 'R-53610',
#  'BEV|Vitasoy|Chrysanthemum Tea': 'R-41528',
#  'BEV|Vitasoy|Coconut': 'R-40489',
#  'BEV|Vitasoy|Green Tea|500ml': 'R-42827',
#  'BEV|Vitasoy|Guava': 'R-40575',
#  'BEV|Vitasoy|Honey Chrysanthem': 'R-40491',
#  'BEV|Vitasoy|Jasmine Tea|500ml': 'R-42826',
#  'BEV|Vitasoy|Lemon Tea': 'R-41668',
#  'BEV|Vitasoy|Low Sugar': 'R-40538',
#  'BEV|Vitasoy|Lychee': 'R-40536',
#  'BEV|Vitasoy|Malt': 'R-40487',
#  'BEV|Vitasoy|Melon': 'R-40488',
#  'BEV|Vitasoy|Oolong Tea|500ml': 'R-53609',
#  'BEV|Vitasoy|Sugarcane': 'R-40490',
#  'BEV|Water|AHA|Blueberry Pom': 'R-58207',
#  'BEV|Water|AHA|Blueberry|Can': 'R-56138',
#  'BEV|Water|AHA|Peach Honey': 'R-56127',
#  'BEV|Water|AHA|Peach|Can': 'R-56142',
#  'BEV|Water|AHA|Watermelon|500ml': 'R-56130',
#  'BEV|Water|Coconut|Blue Monkey': 'R-39283',
#  'BEV|Water|Coconut|Zico|1ltr': 'R-46223',
#  'BEV|Water|Dasani|591ml': 'R-19585',
#  'BEV|Water|Dasani|Berry': 'R-38722',
#  'BEV|Water|Dasani|Black Cherry': 'R-39228',
#  'BEV|Water|Dasani|Citron': 'R-38469',
#  'BEV|Water|Evian|1 liter': 'R-46219',
#  'BEV|Water|Evian|500ml': 'R-46379',
#  'BEV|Water|Fresca|Black Cherry': 'R-53026',
#  'BEV|Water|Fresca|Grapefruit ': 'R-53023',
#  'BEV|Water|Fresca|Peach Citrus': 'R-53022',
#  'BEV|Water|Smart Sparkle|591ml': 'R-46388',
#  'BEV|Water|Smart Sparkle|Apple': 'R-53488',
#  'BEV|Water|Smart Sparkle|Raspbe': 'R-53526',
#  'BEV|Water|Smart Sparkle|Strawb': 'R-53124',
#  'BEV|Water|Smart|1 litre': 'R-55837',
#  'BEV|Water|Smart|591ml': 'R-40732',
#  'BEV|Water|Vitamin|Asst': 'R-22305',
#  'BEV|Water|Vitamin|Essential': 'R-38150',
#  'BEV|Water|Vitamin|Focus': 'R-38175',
#  'BEV|Water|Vitamin|Mega C': 'R-38724',
#  'BEV|Water|Vitamin|Multi V': 'R-38324',
#  'BEV|Water|Vitamin|Rise': 'R-38611',
#  'BEV|Water|Vitamin|Shine': 'R-38152',
#  'BEV|Water|Vitamin|XOXOX': 'R-38323',
#  'BEV|Water|Vitamin|XXX': 'R-38149',
#  'BEV|Yerba Mate|Bulk 12oz': 'R-23628',
#  'BEV|Yerba Mate|Bulk 16oz': 'R-23629',
#  'BEV|Yerba Mate|Classic Gold': 'R-40500',
#  'BEV|Yerba Mate|Cranberry Pom': 'R-38881',
#  'BEV|Yerba Mate|Enlighten Mint': 'R-38189',
#  'BEV|Yerba Mate|Lemon Elation': 'R-38466',
#  'BEV|Yerba Mate|Revel Berry': 'R-38144',
#  'BEV|Yogurt Drink|IOGO|Asst': 'R-23323',
#  'BEV|Yogurt Drink|YOP|Asst': 'R-23332',
#  'BLOW|Sheperds Pie Cass': 'R-54301',
#  'BLOWOUT|Crab Cakes w Ceasar': 'R-54278',
#  'BLOWOUT|PomPom ': 'R-54282',
#  'BLOWOUT|Riblette S/W': 'R-54283',
#  'BLOWOUT|YamChikPatty w CZR': 'R-54281',
#  'BLUEBERRY BERRIES': 'R-39338',
#  'BLUEBERRYFEST|puff pastry': 'R-71857',
#  'BNO| Nachos|Loaded': 'R-64998',
#  'BNO|Achiote Chicken|PLATE': 'R-71173',
#  'BNO|Ancho Rice|SIDE': 'R-71669',
#  'BNO|BEEF|Chimichanga|PLATE': 'R-71472',
#  'BNO|Bowl|Ancho Chicken': 'R-44315',
#  'BNO|Bowl|Ancho Steak': 'R-44310',
#  'BNO|Bowl|Carne Asada': 'R-56801',
#  'BNO|Bowl|Chicken Fajita ': 'R-57179',
#  'BNO|Bowl|Guacamole ': 'R-55154',
#  'BNO|Bowl|Havana|Plant based': 'R-35896',
#  'BNO|Bowl|Latin': 'R-35900',
#  'BNO|Bowl|Poblano&Mushroom': 'R-44301',
#  'BNO|Bowl|Pulled Pork': 'R-44308',
#  'BNO|Bowl|Roja-tots': 'R-17487',
#  'BNO|Bowl|Seasonal Squash': 'R-51218',
#  'BNO|Bowl|Street corn ': 'R-56981',
#  'BNO|Bowl|Super Tofu': 'R-51216',
#  'BNO|BOWL|WHITE BEAN': 'R-53127',
#  'BNO|Breakfast|Molletes': 'R-67814',
#  'BNO|BreakfastBurritoBowl|VEGAN': 'R-61844',
#  'BNO|Burrito| Carne Asada': 'R-62084',
#  'BNO|Burrito|Ancho Chicken': 'R-43587',
#  'BNO|Burrito|Breakfast': 'R-71747',
#  'BNO|Burrito|Chicken Fajita': 'R-62086',
#  'BNO|Burrito|Poblano & Mushroom': 'R-44304',
#  'BNO|Burrito|Pulled Pork': 'R-44303',
#  'BNO|Burrito|Seasonal Squash': 'R-46423',
#  'BNO|Burrito|Steak ': 'R-43580',
#  'BNO|Burrito|Street Corn': 'R-62079',
#  'BNO|Burrito|Super Tofu': 'R-51217',
#  'BNO|Burrito|White Bean ': 'R-44316',
#  'BNO|Burrito|Yam|VEGAN': 'R-71498',
#  'BNO|Calabacitas|PLATE': 'R-71426',
#  'BNO|Camarones Diabla|PLATE': 'R-71459',
#  'BNO|Caserole|Chile Relleno ': 'R-71363',
#  'BNO|Casserole|Mexican Enchilad': 'R-67713',
#  'BNO|Chicken Mole Rojo|PLATE': 'R-71424',
#  'BNO|Chilaquiles': 'R-55116',
#  'BNO|Cilantro Lime rice ': 'R-56956',
#  'BNO|Cuban Mojo Chicken|PLATE': 'R-71431',
#  'BNO|Enfrijoladas|VEGAN': 'R-67815',
#  'BNO|Flauta|3 Bean': 'R-67554',
#  'BNO|Grilled salmon & Red Chimi': 'R-71462',
#  'BNO|Huevos Rancheros': 'R-48488',
#  'BNO|Latin Chicken|PLATE': 'R-71469',
#  'BNO|Mexican Black Beans|SIDE': 'R-71670',
#  'BNO|Mexican Cauliflower Rice': 'R-71546',
#  'BNO|Mexican Lasagna': 'R-67531',
#  'BNO|Pepper & onions|SIDE': 'R-71675',
#  'BNO|Quesadilla|Beyond Meat': 'R-47424',
#  'BNO|Quesadilla|Black Bean': 'R-65763',
#  'BNO|Quesadilla|Chipotle Chick': 'R-47422',
#  'BNO|Quesadilla|Kale & Bean': 'R-57098',
#  'BNO|Quesadilla|Roasted Veg ': 'R-46913',
#  'BNO|Quesadilla|Spin Artichoke': 'R-55133',
#  'BNO|Quesadilla|Spin Mushroom ': 'R-57096',
#  'BNO|Quesadilla|Steak': 'R-70630',
#  'BNO|Red Chile Adobo|Cauliflowe': 'R-71536',
#  'BNO|Red chile Adobo|FlankSteak': 'R-71533',
#  'BNO|Sincronizada ': 'R-71056',
#  'BNO|Stew|Carne Con Tamarindo': 'R-71528',
#  'BNO|Taco|Al Hongo|2Pc': 'R-71317',
#  'BNO|Taco|Al Pastor|2 PC': 'R-67816',
#  'BNO|Taco|Breakfast|2PC': 'R-67813',
#  'BNO|Taco|Carne Asada|2pc': 'R-67714',
#  'BNO|Taco|Carnitas|2pc': 'R-70768',
#  'BNO|Taco|Cauliflower|2PC': 'R-68082',
#  'BNO|Taco|Chicken Tinga|2PC': 'R-67551',
#  'BNO|Taco|Chickpea|2 pc': 'R-67695',
#  'BNO|Taco|Cod': 'R-57239',
#  'BNO|Taco|Crispy Cod|2PC': 'R-71313',
#  'BNO|Taco|Cumin Lime Chicken|2p': 'R-68085',
#  'BNO|Taco|Elote|2 PC': 'R-67715',
#  'BNO|Taco|Fried Chicken|2 PC': 'R-61877',
#  'BNO|Taco|Jackfruit Tinga|2 PC': 'R-71310',
#  'BNO|Taco|Oceanwise prawn|2 PC': 'R-56711',
#  'BNO|Taco|Pollo Asado|2 PC': 'R-68118',
#  'BNO|Taco|Pork belly tajin|2 PC': 'R-61835',
#  'BNO|Taco|Sweet Potato|2pc': 'R-35882',
#  'BNO|Tajin Tots|SIDE': 'R-67696',
#  'BNO|Tofu Breakfast Scramble': 'R-67821',
#  'BNO|Tostada|Cauliflower Cevich': 'R-71509',
#  'BNO|Tostada|Shrimp Ceviche': 'R-67563',
#  'BNO|VEG|Chimichanga|PLATE': 'R-71474',
#  'BOX|BBQ Brisket + 2|ERP': 'R-55811',
#  'BOX|BBQ Salmon + 2|ERP': 'R-47095',
#  'BOX|Breakfast|ERP': 'R-55816',
#  'BOX|Butternut Squash Chili|ERP': 'R-55812',
#  'BOX|Lunch|ERP': 'R-55817',
#  'BOX|Sal Penne Cream Sauce|ERP': 'R-55815',
#  'BOX|Spanish Cod+2|ERP': 'R-55248',
#  'BOX|Vegetables & Guacamole|ERP': 'R-55808',
#  'BOX|Vegetables & Hummus|ERP': 'R-55806',
#  'BOX|Vegetables & Tzaziki|ERP': 'R-55807',
#  'BRKFST POTATO WEDGES': 'R-63582',
#  'BRNCH|Eggs Benny|Blackstone': 'R-48321',
#  'BRNCH|Eggs Benny|Classic Ham': 'R-67352',
#  'BRNCH|Eggs Benny|Roast Mushroo': 'R-67680',
#  'BRNCH|Eggs Benny|Smk Salmon': 'R-48357',
#  'BRNCH|Eggs Benny|Spin &Feta': 'R-48359',
#  'BRNCH|Eggs Benny|TMRW Sausage': 'R-64999',
#  'BRNCH|Quiche|Beyond Sausage': 'R-67182',
#  'BROWNIE (HLCRST)': 'R-64339',
#  'BUTTERNUT SQUASH CHILI': 'R-55677',
#  'C19 SCHOLARS GENERAL': 'R-56140',
#  'C19 TERIYAKI CHICKEN': 'R-56443',
#  'C19|Dessert|NB Cheese Cake Cup': 'R-56104',
#  'C19|HAM ADD 1 SLICE': 'R-56321',
#  'C19|Mac Croquettes plate': 'R-56065',
#  'Calamari Plate': 'R-56368',
#  'CANAPE|AranciniDOZ|FORMAL': 'R-53948',
#  'CANAPE|GazpachoDOZ|FORMAL': 'R-53950',
#  'CANAPE|PizetteDOZ|FORMAL': 'R-53945',
#  'CASATA FALAFEL (VEGAN)': 'R-38246',
#  'CAULIFLOWER|Tikka Plate (Test)': 'R-54718',
#  'CEREAL|Hot|Congee': 'R-31948',
#  'CEREAL|Hot|Oatmeal': 'R-23868',
#  'CHICKEN BURGER KATSU CURRY': 'R-41333',
#  'CHIP LAY BAKED CHEDDAR': 'R-64828',
#  'CHIP SUN FRENCH ONION': 'R-63585',
#  'CHIP SUN GARDEN SALSA': 'R-63587',
#  'CHIP SUN HARVEST CHEDDAR': 'R-63586',
#  'CHOCOLATE CHUNK COOKIE': 'R-65533',
#  'CK|G&G|HMR|Chickpea Curry.': 'R-62731',
#  'CLV|African Gratitude Bowl': 'R-71735',
#  'CLV|Aloo Gobi|BOWL': 'R-36043',
#  'CLV|Biryani|Chicken': 'R-67834',
#  'CLV|Biryani|Vegetable': 'R-68237',
#  'CLV|Butter Chicken ': 'R-62422',
#  'CLV|Chaat Salad 2.0|PLATE': 'R-68234',
#  'CLV|Chana Masala|BOWL': 'R-62424',
#  'CLV|Chapati|VEGAN': 'R-71582',
#  'CLV|Chicken Tikka Masala|BOWL': 'R-68226',
#  'CLV|Chickpea Vindaloo|PLATE': 'R-56827',
#  'CLV|crispy plantain (Alloco)': 'R-71671',
#  'CLV|Dum Aloo|BOWL': 'R-67840',
#  'CLV|Durban Chicken Curry|BOWL': 'R-71456',
#  'CLV|Jollof Rice & Beef': 'R-71477',
#  'CLV|Keralan cashew Chicken': 'R-67838',
#  'CLV|Lamb Curry': 'R-70641',
#  'CLV|Lamb Kadhai': 'R-70640',
#  'CLV|Massaman Beef Curry|BOWL': 'R-45426',
#  'CLV|Pakora|Veggie': 'R-67835',
#  'CLV|Palak Paneer|BOWL': 'R-44414',
#  'CLV|Paneer|Tikka Masala|BOWL': 'R-68230',
#  'CLV|Raita|SIDE': 'R-62197',
#  'CLV|Red Lentil Curry|PLATE': 'R-67831',
#  'CLV|Salad|Chaat|PLATE': 'R-68231',
#  'CLV|Samosa|Beef': 'R-41669',
#  'CLV|Samosa|Chicken': 'R-64149',
#  'CLV|Samosa|Vegetable': 'R-48242',
#  'CLV|South African Chakalaka': 'R-71545',
#  'CLV|Spicy Dahl|Chit Chaat': 'R-32774',
#  'CLV|Spicy Dahl|PLATE': 'R-37053',
#  'CLV|Tandoori Chicken|PLATE': 'R-54720',
#  'CLV|Tofu Tikka Masala|BOWL': 'R-68229',
#  'CNA|Pizza|4 Cheese': 'R-57087',
#  'CNA|Pizza|Bacon & Egg ': 'R-54386',
#  'CNA|Pizza|Capicoli': 'R-54383',
#  'CNA|Pizza|Garden Vegetable': 'R-57080',
#  'CNA|Pizza|Hawaiian': 'R-57046',
#  'CNA|Pizza|Margherita': 'R-8355',
#  'CNA|PIZZA|Mediterranean': 'R-67173',
#  'CNA|Pizza|Mushroom pesto ': 'R-54381',
#  'CNA|Pizza|Pepperoni': 'R-61829',
#  'CNA|Pizza|Pesto Pollo': 'R-48838',
#  'CNA|PIZZA|Philly Cheese Steak': 'R-67347',
#  'CNA|Pizza|Salami & mushroom': 'R-67538',
#  'CNA|Pizza|Sausage ': 'R-61831',
#  'CNA|Pizza|Smoked Salmon ': 'R-54382',
#  'CNA|PIZZA|Vegan Salmon': 'R-66041',
#  'COCOA BITES - FRESHII': 'R-64979',
#  'COKE STARLIGHT ZERO': 'R-67590',
#  'COKE ZERO VANILLA 500 ML': 'R-63861',
#  'CONGEE': 'R-38201',
#  'CONTAINER|Own Container Credit': 'R-13175',
#  'CONTAINER|Paper Cup Charge': 'R-46217',
#  'COOKED|Cilantro Lime rice AR': 'R-56805',
#  'CRUNCHY LENTILS - SPICE': 'R-64324',
#  'CYCLONE PINEAPPPLE LEMON STRAW': 'R-66874',
#  'DDP YOGURT RAISINS': 'R-64332',
#  'DES|Bar|Sundae': 'R-34663',
#  'DES|Biscotti|MC|Asst': 'R-52808',
#  "DES|Biscotti|Wendel's|Almond ": 'R-40496',
#  "DES|Biscotti|Wendel's|Asst|GF": 'R-24464',
#  "DES|Biscotti|Wendel's|Asst|GF.": 'R-39331',
#  "DES|Biscotti|Wendel's|Chocolat": 'R-40581',
#  'DES|Brownie|Black Bean': 'R-47480',
#  'DES|Brownie|MC': 'R-52792',
#  'DES|Cake|Cheesecake|New York': 'R-22312',
#  'DES|Cake|Rondine Tiramisu': 'R-48241',
#  'DES|Cake|Slice Asst': 'R-22310',
#  'DES|Cake|Valentine Choco Heart': 'R-55145',
#  'DES|Cheesecake|Chuckanut|Berry': 'R-40013',
#  'DES|Cheesecake|Chuckanut|Choco': 'R-42345',
#  'DES|Cheesecake|Chuckanut|GF': 'R-23333',
#  'DES|Cheesecake|Chuckanut|GF.': 'R-30535',
#  'DES|Cheesecake|Chuckanut|NY': 'R-38924',
#  'DES|Cheesecake|Valentine|Slice': 'R-24556',
#  'DES|Chocolate Pudding Praline': 'R-55289',
#  'DES|Churro': 'R-43301',
#  'DES|Cookie|Easter Egg|CK': 'R-56141',
#  'DES|Cookie|Easter Egg|Trump': 'R-34660',
#  'DES|Cookie|Easter Sugar': 'R-56139',
#  'DES|Cookie|Festive': 'R-40975',
#  'DES|Cookie|Pumpkin Sugar|CK': 'R-39459',
#  'DES|Cookie|Pumpkin Sugar|CK.': 'R-39844',
#  'DES|Cookie|Shamrock': 'R-49713',
#  'DES|Cookie|Shortbread': 'R-33034',
#  'DES|Cookie|Shortbread.': 'R-40974',
#  'DES|Cookie|Small': 'R-19605',
#  'DES|Cookie|Supreme Asst': 'R-20399',
#  'DES|Cookie|Valentine Heart|CK': 'R-49301',
#  'DES|Cookie|Valentine Heart|Tru': 'R-55070',
#  'DES|Cookie|Valentine Sandwich ': 'R-55069',
#  "DES|Cookie|Wendel's|Almond": 'R-45849',
#  "DES|Cookie|Wendel's|Choc Chip": 'R-40508',
#  "DES|Cookie|Wendel's|Ginger": 'R-40021',
#  "DES|Cookie|Wendel's|Ginger.": 'R-20381',
#  'DES|Cookie|Xmas|Ginger Bear': 'R-48895',
#  'DES|Cookie|Xmas|Ginger People': 'R-33032',
#  'DES|Cookie|Xmas|Ginger People.': 'R-41328',
#  'DES|Cookie|Xmas|GingerMan|Trum': 'R-48237',
#  'DES|Cookie|Xmas|Gingersnap': 'R-33031',
#  'DES|Cookie|Xmas|Snowflake': 'R-54261',
#  'DES|Cookie|Xmas|Tree/Bell': 'R-54186',
#  'DES|Eclair|Chocolate': 'R-22313',
#  'DES|Hot Cross Bun': 'R-55862',
#  'DES|Jello|Asst': 'R-22309',
#  'DES|Muffin|Blueberry|GF': 'R-23335',
#  'DES|Pie|Lemon Meringue|Slice ': 'R-53141',
#  'DES|Pie|Pecan & Cream|Slice': 'R-24807',
#  'DES|Pie|Slice Asst': 'R-22311',
#  'DES|Pudding|Brown Rice ': 'R-48864',
#  'DES|Rice Krispy|Valentine': 'R-23940',
#  'DES|Soft Serve|8oz': 'R-30499',
#  "DES|Square|Wendel's|Brownie": 'R-40497',
#  "DES|Square|Wendel's|Nanaimo": 'R-39816',
#  'DES|Square|Whole| Asst': 'R-22314',
#  'DES|Square|Whole| Asst.': 'R-21283',
#  'DES|Strudel|Asst': 'R-22861',
#  'DES|Tart||Pumpkin|CK': 'R-47092',
#  'DES|Tart|Butter': 'R-23889',
#  'DES|Tart|Lemon|3" ': 'R-33536',
#  'DES|Tart|Mincemeat Mini': 'R-33033',
#  'DES|Tart|Mincemeat|CK': 'R-40978',
#  "DES|Tart|Wendel's|Buttertart": 'R-40015',
#  "DES|Tart|Wendel's|Choc Pecan": 'R-22327',
#  "DES|Tart|Wendel's|Choc Pecan.": 'R-39815',
#  'DESSERT|Choc.Valent|cookie': 'R-24557',
#  'DIM SUM|Beef Balls (3)': 'R-40736',
#  'DIM SUM|Bun| Chicken (1)': 'R-22843',
#  'DIM SUM|Bun|BBQ Pork (1)': 'R-38424',
#  'DIM SUM|Combo M&M': 'R-54728',
#  'DIM SUM|Gyoza Chicken (3)': 'R-30481',
#  'DIM SUM|Gyoza Veg (3)': 'R-30482',
#  'DIM SUM|Shrimp Corn Dumpling 3': 'R-53045',
#  'DIM SUM|Shrimp Ha Gow (3)': 'R-38421',
#  'DIM SUM|Shrimp Pork Siu Mai(3)': 'R-38423',
#  'DIM SUM|SOUP|Won Ton': 'R-22240',
#  'DIM SUM|Wonton|Deep Fried (3)': 'R-61777',
#  'DIM SUM|Wrap Sticky Rice|SIDE': 'R-38420',
#  'DNR||Blueberry Compote|SIDE': 'R-68193',
#  'DNR||Grilled Cheese|Italian': 'R-54079',
#  'DNR|Add Bacon|2 pcs': 'R-24157',
#  'DNR|BlackBean Hash|VEGAN': 'R-61823',
#  'DNR|Blood Orange Pancake|2 PC': 'R-56987',
#  'DNR|Buffalo Chicken Fries': 'R-67593',
#  'DNR|Buffalo Wings|TAILGATE': 'R-70769',
#  'DNR|Burger|bacon & Egg': 'R-71655',
#  'DNR|Burger|Bacon Blue': 'R-61828',
#  'DNR|Burger|Bacon Jam & Egg': 'R-50706',
#  'DNR|Burger|BBQ Chicken': 'R-54583',
#  'DNR|Burger|Buffalo chicken': 'R-71328',
#  'DNR|Burger|Classic Beef': 'R-26776',
#  'DNR|Burger|Classic Cheese': 'R-50697',
#  'DNR|Burger|Classic Chicken': 'R-62685',
#  'DNR|Burger|Feast Beast ': 'R-51200',
#  'DNR|Burger|FEAST SIGNATURE': 'R-52805',
#  'DNR|Burger|Garden Chicken': 'R-51202',
#  'DNR|Burger|Greek Chicken': 'R-50662',
#  'DNR|Burger|Hawaiian Chicken': 'R-26781',
#  'DNR|Burger|Kim chi ': 'R-50704',
#  'DNR|Burger|Onion Ring ': 'R-50709',
#  'DNR|Burger|Queso Fiesta ': 'R-51203',
#  'DNR|Burger|Spicy black bean': 'R-50702',
#  'DNR|Burger|Swiss Mushroom': 'R-50655',
#  'DNR|Burger|Tandoori TMRW|VEGAN': 'R-64843',
#  'DNR|Buttermilk Pancakes|2 pcs': 'R-44876',
#  'DNR|Dog|Cheesesteake|TAILGATE': 'R-70798',
#  'DNR|Dog|Kansas City|TAILGATE': 'R-70797',
#  'DNR|Egg Almost Any Style|Side': 'R-52754',
#  'DNR|Fries|Potato': 'R-26788',
#  'DNR|FRIES|Spicy Spiral': 'R-71601',
#  'DNR|Grilled Cheese|Bacon Avo': 'R-50669',
#  'DNR|Grilled Cheese|Classic': 'R-50665',
#  'DNR|Grilled Cheese|Ham&Cheese': 'R-54762',
#  'DNR|Grilled Cheese|PestoTomato': 'R-28254',
#  'DNR|Grilled Cheese|Philly': 'R-61825',
#  'DNR|Grilled Cheese|Pulled Pork': 'R-61826',
#  'DNR|Grilled Cheese|Spicy Jalap': 'R-50668',
#  'DNR|Grilled Cheese|Turkey&Swis': 'R-67998',
#  'DNR|Hashbrowns|RATIO': 'R-67920',
#  'DNR|Hearty VeganChili|TAILGATE': 'R-57004',
#  'DNR|Mini Corndogs': 'R-71297',
#  'DNR|Onion Ring|SIDE': 'R-56090',
#  'DNR|Onion Rings': 'R-71656',
#  'DNR|Pancake|Apple Cinnamon': 'R-70032',
#  'DNR|Pancake|BananaCaramel|2pc': 'R-53360',
#  'DNR|Pancake|Blueberry': 'R-68919',
#  'DNR|Pancake|Blueberry basil': 'R-70992',
#  'DNR|Pancake|Peaches & Cream': 'R-50634',
#  'DNR|Pancake|Pumpkin Spice|2PC': 'R-50647',
#  'DNR|Pancake|Rasp Choc Chip': 'R-51192',
#  'DNR|Pancakes|Blueberry|2PC': 'R-26799',
#  'DNR|Poutine|Classic': 'R-26786',
#  'DNR|Roasted Mushrooms': 'R-71518',
#  'DNR|Sandwich|Crispy Cod': 'R-56458',
#  'DNR|SauteeSpinach & Kale|SIDE': 'R-71651',
#  'DNR|Scrambled Eggs|SIDE': 'R-27422',
#  'DNR|Side Grilled Tomato|1pc': 'R-46336',
#  'DNR|Spiced French Toast': 'R-27334',
#  'DNR|Toast|Smashed Chickpea ': 'R-71577',
#  'DNR|Tuna Melt': 'R-67562',
#  'DNR|Turkey Bfast Sausage|Side': 'R-27423',
#  'DNR|Vegan Breakfast|PLATE': 'R-71576',
#  'DNR|Wrap|Chicken Bacon Ranch': 'R-71355',
#  'DNRlPhilly Cheese Steak': 'R-52788',
#  'DO NOT USE': 'R-54780',
#  'do not use..': 'R-55810',
#  'DONUTS (Hillcrest)': 'R-67030',
#  'DRESSED|Arugula|SIDE': 'R-62191',
#  'DRIED MANGO': 'R-64331',
#  'DSRT|HAND PIE A LA MODE': 'R-64911',
#  'EVENT|Bev|Strawberry Milkshake': 'R-24630',
#  'FEAT|Black bean soup|350ml': 'R-54947',
#  'FLEX\\ TofuTeriyaki bowl': 'R-54329',
#  'FLEX|Baked Pasta': 'R-55840',
#  'FLEX|Japchae Noodles&Vegetable': 'R-54328',
#  'FLEX|Mexican Yam Bowl': 'R-55948',
#  'FLEX|Ramen Bowl': 'R-55947',
#  'FLEX|Salad|Thai Cucumber': 'R-62600',
#  'FLEX|Side Salad|Strawberry vin': 'R-55969',
#  'FLEX|Singapore Beef plate': 'R-55939',
#  'FLEX|Singapore Tofu Plate': 'R-55940',
#  'FLEX|Spicy Caesar|SIDE': 'R-53848',
#  'FLEX|Teriyaki Beef Bowl': 'R-55373',
#  'FLEX|Vegan Pasta Bake': 'R-55970',
#  'FLX| BEEF & MUSHROOM STEW': 'R-65035',
#  'FLX| BEEF& MUSHROOM STEW+1': 'R-65034',
#  'FLX| Pastrami On Rye': 'R-57050',
#  'FLX|Banh Mi Tofu|PTN': 'R-47210',
#  'FLX|Beef Vindaloo 2.0': 'R-55777',
#  'FLX|Beef Vindaloo Plate': 'R-44403',
#  'FLX|Brown Rice|PTN': 'R-53069',
#  'FLX|Cashew Dipping Sauce|Thai': 'R-56632',
#  'FLX|Corned Beef OF Sandwich +1': 'R-55826',
#  'FLX|Corned Beef Sandwich': 'R-55830',
#  'FLX|Cyprus Mannoush Pork|Oas': 'R-47269',
#  'FLX|Cyprus Mannoush Veg|Oas': 'R-47611',
#  'FLX|Falafel Plate': 'R-44357',
#  'FLX|Feta Cheese|ADD': 'R-42426',
#  'FLX|Fish IN Chips ': 'R-57002',
#  'FLX|Japchae V2|Street': 'R-56116',
#  'FLX|Kale & Cabbage Slaw|SIDE': 'R-62194',
#  'FLX|Kettle Chips': 'R-62494',
#  'FLX|Lemon Garlic Rockfish': 'R-56707',
#  'FLX|Lettuce Wrap Tofu|Street': 'R-55302',
#  'FLX|Lettuce Wrap|PORK LARB': 'R-55240',
#  'FLX|Omelette Bar Veggie': 'R-55221',
#  'FLX|Omlette w Protein': 'R-55220',
#  'FLX|Penne & Meatballs|Diner': 'R-53838',
#  'FLX|Polenta Fries w dip|GYV': 'R-56708',
#  'FLX|Porchetta sandwich': 'R-64978',
#  'FLX|Ras El  Apricot Rice': 'R-46793',
#  'FLX|Salad Wrap + Cashew Sauce': 'R-56877',
#  'FLX|Seafood Pancake|STR': 'R-51504',
#  'FLX|Side Hummus|Med': 'R-56876',
#  'FLX|Side Marinated Olives|Med': 'R-44390',
#  'FLX|SLIDERS|Surf & Turf ': 'R-56916',
#  'FLX|Spring Salad Strawberry': 'R-55827',
#  'FLX|Sultana Pilaf|SIDE': 'R-44370',
#  'FLX|Teppanyaki Beef|Street': 'R-51275',
#  'FLX|Traditional Bannock |SIDE': 'R-56954',
#  'FLX|Turkey OF Sandwich': 'R-55831',
#  'FLX|Turkey OF Sandwich +1': 'R-55825',
#  'FLX|Veg Pakora w Chutney|3 pc': 'R-38612',
#  'FLX|Viet Spng Roll + Nuoc Cham': 'R-47211',
#  'FLX|West coast Chowder AR': 'R-56955',
#  'FLX|WW Penne & Cheese|Diner': 'R-51272',
#  'FNH|Funfetti cake|PTN': 'R-64755',
#  'FNH|Moroccan Beet Salad|SIDE': 'R-64405',
#  'FNO|Baked 4 Cheese Penne|PTN': 'R-67546',
#  'FNO|Flatbread|Bruschetta': 'R-50859',
#  'FREE|Coffee|12 oz|United Way': 'R-54005',
#  'FREE|Green-To-Go|Apple Asst': 'R-47000',
#  'FREE|Green-To-Go|Banana': 'R-47006',
#  'FREE|Green-To-Go|Fruit': 'R-47001',
#  'FREE|Green-To-Go|Orange': 'R-47027',
#  'FRESH FRUIT TART': 'R-64350',
#  'FRUIT|Apple|Ambrosia': 'R-24109',
#  'FRUIT|Apple|Braeburn': 'R-23912',
#  'FRUIT|Apple|Fuji': 'R-23863',
#  'FRUIT|Apple|fUJI 64': 'R-48607',
#  'FRUIT|Apple|Gala': 'R-20406',
#  'FRUIT|Apple|Golden Delicious': 'R-22846',
#  'FRUIT|Apple|Granny Smith': 'R-20510',
#  'FRUIT|Apple|MacIntosh': 'R-22847',
#  'FRUIT|Apple|Pink Lady': 'R-23946',
#  'FRUIT|Apple|Red Delicious': 'R-20511',
#  'FRUIT|Avocado': 'R-20405',
#  'FRUIT|Banana': 'R-22849',
#  'FRUIT|Blackberry|Basket': 'R-24091',
#  'FRUIT|Blueberry|Basket.': 'R-24092',
#  'FRUIT|Blueberry|Cup': 'R-52600',
#  'FRUIT|Canteloupe|1/4 cut': 'R-23642',
#  'FRUIT|Cup|Grapes': 'R-23634',
#  'FRUIT|Grapefruit': 'R-22853',
#  'FRUIT|Grapefruit|1/2 Cut': 'R-22854',
#  'FRUIT|Honeydew|1/4 Cut': 'R-24112',
#  'FRUIT|Kiwi': 'R-22857',
#  'FRUIT|Lemon': 'R-54841',
#  'FRUIT|Mandarin': 'R-23317',
#  'FRUIT|Nectarine': 'R-30502',
#  'FRUIT|Orange Cut': 'R-22856',
#  'FRUIT|Orange Whole': 'R-22855',
#  'FRUIT|Peach': 'R-30534',
#  'FRUIT|Pear|Asian': 'R-22858',
#  'FRUIT|Pear|Bartlet': 'R-30629',
#  'FRUIT|Pear|Green Anjous': 'R-22944',
#  'FRUIT|Pink Grapefruit|Cup': 'R-48609',
#  'FRUIT|Plum': 'R-30500',
#  'FRUIT|Plum|Cup': 'R-46394',
#  'FRUIT|Raspberry|Basket.': 'R-40020',
#  'FRUIT|Strawberry|Basket': 'R-52752',
#  'FRUIT|Watermelon': 'R-24810',
#  'G&G||Brownie 2-Bite|70g': 'R-38657',
#  'G&G|Bar|Granola|UBC': 'R-22320',
#  'G&G|Bar|Kashi|Almond Butter': 'R-53611',
#  'G&G|Bar|Kashi|Chocolate Banana': 'R-45858',
#  'G&G|Bar|Kashi|Cranberr Coconut': 'R-53933',
#  'G&G|Bar|Kashi|Espresso Choco': 'R-45857',
#  'G&G|Bar|Kashi|Pistachio Fig': 'R-45860',
#  'G&G|Bar|Kashi|Raspberry Choco': 'R-45859',
#  'G&G|Bar|Kind| Almond Caramel': 'R-49316',
#  'G&G|Bar|Kind| Almond Coconut': 'R-47459',
#  'G&G|Bar|Kind| Almond Mint Dark': 'R-54977',
#  'G&G|Bar|Kind| Honey Roast Nut': 'R-52937',
#  'G&G|Bar|Kind|Almond Sea Salt ': 'R-41684',
#  'G&G|Bar|Kind|Cashew Blueberry': 'R-42323',
#  'G&G|Bar|Kind|Cashew Raspberry': 'R-42326',
#  'G&G|Bar|Kind|Chewy Dark Choco': 'R-40924',
#  'G&G|Bar|Kind|Chia Mango Apple ': 'R-53520',
#  'G&G|Bar|Kind|Dark Choc Cherry': 'R-49800',
#  'G&G|Bar|Kind|Fruit & Nut': 'R-52938',
#  'G&G|Bar|Kind|Maple Glaze Pecan': 'R-55674',
#  'G&G|Bar|Kind|Maple Pumpkin See': 'R-40925',
#  'G&G|Bar|Kind|Oats & Honey': 'R-40926',
#  'G&G|Bar|Kind|Peanut Butter ': 'R-41527',
#  'G&G|Bar|Kind|Peanut Chewy': 'R-40930',
#  'G&G|Bar|Nutrigrain|Blueberry': 'R-40506',
#  'G&G|Bar|Nutrigrain|Mixed Berry': 'R-40505',
#  'G&G|Bar|Nutrigrain|Strawberry': 'R-40498',
#  'G&G|Bar|Solo| Peanut Caramel': 'R-55471',
#  'G&G|Bar|Solo|Chocolate': 'R-38214',
#  'G&G|Bar|Solo|Chocolate Brownie': 'R-55146',
#  'G&G|Bar|Solo|Chocolate Coconut': 'R-38465',
#  'G&G|Bar|Solo|ChocolateMandarin': 'R-38543',
#  'G&G|Bar|Solo|Dark Chocolate ': 'R-38605',
#  'G&G|Bar|Solo|Lemon Lift': 'R-38774',
#  'G&G|Bar|Solo|Mocha Fudge': 'R-38321',
#  'G&G|Bar|Solo|Peanut Caramel ': 'R-55676',
#  'G&G|Bar|Solo|Peanut Power': 'R-38606',
#  'G&G|Bar|Solo|White Chocolate': 'R-38918',
#  'G&G|Breakfast Round |Asst': 'R-42824',
#  'G&G|Cereal Cold|Large| & Milk': 'R-23872',
#  'G&G|Cereal Cold|Large|Dry': 'R-23873',
#  'G&G|Cereal Cold|Small| & Milk': 'R-23870',
#  'G&G|Cereal Cold|Small|Dry': 'R-23871',
#  'G&G|Cereal Cup Chia Plain': 'R-37859',
#  'G&G|Cereal Cup Mango': 'R-37858',
#  'G&G|Chicken Breast Grilled': 'R-55668',
#  'G&G|CHICKPEA CURRY': 'R-64150',
#  'G&G|Chips|Hardbite|Bbq': 'R-38654',
#  'G&G|Chips|Hardbite|Jalapeno': 'R-39069',
#  'G&G|Chips|Hardbite|Natural': 'R-38726',
#  'G&G|Chips|Hardbite|Salt Vinega': 'R-38188',
#  'G&G|Chips|Hardbite|Wild Onion': 'R-38725',
#  'G&G|Chocolate Parfait|Pudding': 'R-55974',
#  'G&G|Coconut Cluster|Cranberry': 'R-54244',
#  'G&G|Coconut Cluster|Super Seed': 'R-54243',
#  'G&G|Cup|Banana Chips|DDP': 'R-32633',
#  "G&G|Cup|Bob's|Oats Apple ": 'R-40931',
#  "G&G|Cup|Bob's|Oats Blueberry": 'R-40929',
#  "G&G|Cup|Bob's|Oats Classic": 'R-41331',
#  "G&G|Cup|Bob's|Oats Maple": 'R-40923',
#  'G&G|Cup|Cereal Variety': 'R-22860',
#  'G&G|Cup|Cereal|Froot Loops': 'R-40526',
#  'G&G|Cup|Cereal|Frosted Flakes': 'R-42349',
#  'G&G|Cup|Cereal|Rice Krispies': 'R-40507',
#  'G&G|Cup|Choco Coco|Happy Plane': 'R-45958',
#  'G&G|Cup|Cranberry Mix': 'R-55067',
#  'G&G|Cup|Fruit & Nut': 'R-46364',
#  'G&G|Cup|PB Bites|Happy Planet': 'R-45957',
#  'G&G|Cup|Raw Energy Mix|DDP': 'R-42571',
#  'G&G|Cup|Trail Mix': 'R-46363',
#  'G&G|Cup|Yogurt Raisins|DDP': 'R-42603',
#  'G&G|Dinner Roll': 'R-23869',
#  'G&G|Dip|Classic Hummus (Vegan)': 'R-55832',
#  'G&G|Dip|Sauce Asst': 'R-46316',
#  'G&G|Dip|Southwestern (Vegan)': 'R-38649',
#  'G&G|Egg Hard Boiled': 'R-38895',
#  'G&G|HMR|Paneer Cauliflower ': 'R-40734',
#  'G&G|HMR|Pasta of the Week': 'R-39326',
#  'G&G|HMR|Salmon Dinner': 'R-55729',
#  'G&G|HMR|Spaghetti Meatball': 'R-54795',
#  'G&G|Homestyle|Brownie 2-Bite ': 'R-38801',
#  'G&G|Homestyle|Macaroon 2-Bite': 'R-40494',
#  'G&G|Homestyle|Macaroon Choc ': 'R-40024',
#  'G&G|Italian Sub Sandwich': 'R-55177',
#  'G&G|KARAAGE CHICKEN +SLAW': 'R-50362',
#  'G&G|Muffin|English': 'R-30623',
#  'G&G|Novelty|Cookies & Cream': 'R-43013',
#  'G&G|Novelty|Fudgesicle': 'R-22959',
#  'G&G|Novelty|Giant Cookie': 'R-38337',
#  'G&G|Novelty|King Cone|Caramel': 'R-38723',
#  'G&G|Novelty|King Cone|Strawber': 'R-38146',
#  'G&G|Novelty|King Cone|Vanilla': 'R-38298',
#  'G&G|Novelty|Klondike|Sandwich': 'R-33349',
#  'G&G|Novelty|Klondike|Sandwich.': 'R-55103',
#  'G&G|Novelty|Magnum|Almond': 'R-38297',
#  'G&G|Novelty|Magnum|Caramel ': 'R-38296',
#  'G&G|Novelty|Magnum|Choc Vanill': 'R-38300',
#  'G&G|Novelty|Magnum|Cookies Crm': 'R-38393',
#  'G&G|Novelty|Magnum|Infinity': 'R-38293',
#  'G&G|Novelty|Magnum|Raspberry': 'R-38301',
#  'G&G|Novelty|Magnum|Strawberry': 'R-49737',
#  'G&G|Novelty|Popsicle': 'R-38767',
#  'G&G|Novelty|Popsicle|Cyclone': 'R-22129',
#  'G&G|Novelty|Popsicle|Minion': 'R-43012',
#  'G&G|Novelty|Popsicle|SpongeBob': 'R-38636',
#  'G&G|Novelty|Reese Cup': 'R-20403',
#  'G&G|Parfait Rasp Cheescake': 'R-48912',
#  'G&G|PEPPERONI STIX': 'R-64291',
#  'G&G|Pickle On A Stick': 'R-54188',
#  'G&G|Popcorn Skinny|Original': 'R-55673',
#  'G&G|Pot|Beet Hummus (Vegan)': 'R-53125',
#  'G&G|Pot|Berries & Yogurt': 'R-52795',
#  'G&G|Pot|Chia Matcha ': 'R-46314',
#  'G&G|Pot|Crudite (Vegan)': 'R-38900',
#  'G&G|Pot|Crunchy Raw Root Veg': 'R-38907',
#  'G&G|Pot|Mango Pudding': 'R-66029',
#  'G&G|Pot|Overnight Quinoa.': 'R-46315',
#  'G&G|Pot|Pudding Chia|Vegan': 'R-52794',
#  'G&G|Pot|Pumpkin Chia': 'R-47138',
#  'G&G|Pot|Pumpkin Pie Chia.': 'R-46743',
#  'G&G|Pot|Salt Caramel Parfait': 'R-38327',
#  'G&G|Pot|Salted Caramel Parfait': 'R-33924',
#  'G&G|Pot|Tropical Fruit.': 'R-38394',
#  'G&G|Pot|Wild Berry Parfait': 'R-53137',
#  'G&G|Pretzel|Pizza': 'R-22904',
#  'G&G|QUICHE|RATIO': 'R-65920',
#  'G&G|Reuben Sandwich': 'R-56093',
#  'G&G|Salad|Berries & Quinoa': 'R-38412',
#  'G&G|Salad|Caesar Kale ': 'R-53718',
#  'G&G|Salad|Caesar Kale Chicken': 'R-38328',
#  'G&G|Salad|Cobb Chicken': 'R-53005',
#  'G&G|Salad|Cobb Vegetarian': 'R-53004',
#  'G&G|Salad|Crunchy Kale': 'R-38396',
#  'G&G|Salad|Fiesta Ensalada': 'R-53521',
#  'G&G|Salad|Fiesta Ensalada Chix': 'R-52796',
#  'G&G|Salad|Medit Chickpea Salmo': 'R-54187',
#  'G&G|Salad|Mediterran Chickpea': 'R-38345',
#  'G&G|Salad|Mediterranean': 'R-53525',
#  'G&G|Salad|Nicoise Salmon': 'R-52797',
#  'G&G|Salad|Nicoise Tofu': 'R-38329',
#  'G&G|Salad|Super Food Salmon': 'R-45735',
#  'G&G|Salad|Super Food.': 'R-46818',
#  'G&G|Sand|Bacon Cheddar Tomato': 'R-52799',
#  'G&G|Sand|Cheese & Ham': 'R-38331',
#  'G&G|Sand|Cranchier Chicken': 'R-52800',
#  'G&G|Sand|Salmon Salad.': 'R-54006',
#  'G&G|Sand|Veggie Delight': 'R-47022',
#  'G&G|SNACK|BLUE MONK COCO CHIPS': 'R-64811',
#  'G&G|Snack|Cheese Slice|Cheddar': 'R-44178',
#  'G&G|Snack|Cheese|Monterey Jack': 'R-35930',
#  'G&G|Snack|Cheesestring|Cheddar': 'R-55359',
#  'G&G|Snack|Crispy Mini|BBQ': 'R-34368',
#  'G&G|Snack|Crispy Mini|Sour Crm': 'R-44136',
#  'G&G|Snack|Crunchy Lentil|BBQ': 'R-53934',
#  'G&G|Snack|Crunchy Lentil|Lite': 'R-53027',
#  'G&G|Snack|Crunchy Lentil|Salt': 'R-54208',
#  'G&G|Snack|Edamame|BBQ|250g': 'R-41931',
#  'G&G|Snack|Energy Mix|DDP': 'R-39303',
#  'G&G|Snack|Hummus Garlic': 'R-53711',
#  'G&G|Snack|Hummus Original': 'R-49714',
#  'G&G|Snack|Hummus Red Pepper': 'R-53723',
#  'G&G|Snack|Lentil|BBQ|Small': 'R-53122',
#  'G&G|Snack|Lentil|Lite|Small': 'R-54197',
#  'G&G|Snack|Lil Peps|Honey Garli': 'R-33355',
#  'G&G|Snack|Naked|Hearty Tamari': 'R-54727',
#  'G&G|Snack|Naked|Maple Almond': 'R-55022',
#  'G&G|Snack|Naked|Wasabi-Me': 'R-47717',
#  'G&G|Snack|Naked|Wholesome Yogi': 'R-54726',
#  'G&G|SNACK|PITA CHIPS': 'R-64759',
#  'G&G|Snack|Turkey Pepperoni Chs': 'R-24443',
#  'G&G|Spread|Almond Butter': 'R-53020',
#  'G&G|Spread|ButterMargarine|Ptn': 'R-22941',
#  'G&G|Spread|Cream Cheese|Ptn': 'R-20388',
#  'G&G|Spread|Jam & Peanut Butter': 'R-13177',
#  'G&G|Spread|Nutella|Ptn': 'R-22899',
#  'G&G|Sushi|California Crunch ': 'R-47663',
#  'G&G|Sushi|California Nigiri ': 'R-22967',
#  'G&G|Sushi|California Roll': 'R-22972',
#  'G&G|Sushi|California Roll Comb': 'R-23318',
#  'G&G|Sushi|CaliforniaSpicy Roll': 'R-38889',
#  'G&G|Sushi|Chicken Honey Bowl': 'R-54453',
#  'G&G|Sushi|Chicken Teriyaki Bow': 'R-25025',
#  'G&G|Sushi|Cucumber Roll': 'R-22966',
#  'G&G|Sushi|Fuji Roll Combo': 'R-22971',
#  'G&G|Sushi|Futomaki Roll 5pc': 'R-47460',
#  'G&G|Sushi|Korean Shrimp Bowl': 'R-53046',
#  'G&G|Sushi|Mango Shrimp| 9pc': 'R-41927',
#  'G&G|Sushi|Philadelphia  Roll': 'R-24093',
#  'G&G|Sushi|Red Dragon Roll': 'R-22970',
#  'G&G|Sushi|Salmon Teriyaki Bowl': 'R-54843',
#  'G&G|Sushi|Veg Salad Roll': 'R-47478',
#  'G&G|Sushi|Vegetable Salad Roll': 'R-22968',
#  'G&G|Sushi|Yokyo Combo': 'R-53154',
#  'G&G|Toast Slice': 'R-34837',
#  'G&G|Tofu Dessert|Almond': 'R-40495',
#  'G&G|Tofu Dessert|Coconut': 'R-39811',
#  'G&G|Tofu Dessert|Custard': 'R-40510',
#  'G&G|Tofu Dessert|Peach Mango': 'R-61776',
#  'G&G|Tortilla Wrap': 'R-48657',
#  'G&G|Tuna Noodle Box': 'R-54189',
#  'G&G|Valentine|Chia Pudding': 'R-55073',
#  'G&G|Wrap|Beef': 'R-30678',
#  'G&G|Wrap|Bkfstt|Ham & Cheese': 'R-52804',
#  'G&G|Wrap|Bkfstt|Mediterranean': 'R-52802',
#  'G&G|Wrap|Chickpea & Spinach': 'R-20401',
#  'G&G|Wrap|Veggie|Simply Curry': 'R-30650',
#  'G&G|Yogurt|Blueberry|Stirred': 'R-42608',
#  'G&G|Yogurt|Fieldberry|Stirred': 'R-42604',
#  'G&G|Yogurt|French Vanilla|FF': 'R-38186',
#  'G&G|Yogurt|Greek|Asst': 'R-42486',
#  'G&G|Yogurt|Greek|Asst.': 'R-42485',
#  'G&G|Yogurt|Greek|Strawberry': 'R-42607',
#  'G&G|Yogurt|Peach|FF': 'R-38185',
#  'G&G|Yogurt|Peach|Stirred': 'R-42605',
#  'G&G|Yogurt|Raspberry|Stirred': 'R-39809',
#  'G&G|Yogurt|Strawberry|FF': 'R-39066',
#  'G&G|Yogurt|Strawberry|Stirred': 'R-52809',
#  'G&G|Yogurt|Strawberry|Stirred.': 'R-42606',
#  'GINGER ALE - DIET 500ml': 'R-63581',
#  'Gold Peak Natural Peach': 'R-66472',
#  'GOUDA BOMBS (3pc)': 'R-64341',
#  'GR|Bircher Muesli|VEGAN': 'R-61846',
#  'GR|Chicken Apple Baguette': 'R-56802',
#  'GR|Ham & Cheese On Sourdough': 'R-57054',
#  'GR|Oats|Banana Almond Overnite': 'R-55117',
#  'GR|Oats|Steel Cut|Maple Apple': 'R-56966',
#  'GR|Oats|Steel Cut|Spicd Pmpkn': 'R-57345',
#  'GR|Oats|Steel Cut|Strawberry': 'R-56959',
#  'GR|Salad|Beet & Arugula': 'R-55132',
#  'GR|Salad|Chopped Thai': 'R-62051',
#  'GR|Salad|Cobb': 'R-61836',
#  'GR|Salad|Ensalada Mexicana': 'R-38248',
#  'GR|Salad|Greek ': 'R-51265',
#  'GR|Salad|Honey Sesame Chicken': 'R-35749',
#  'GR|Salad|Kale & Quinoa': 'R-56852',
#  'GR|Salad|Spicy Caesar': 'R-35751',
#  'GR|Salad|Spinach': 'R-61838',
#  'GR|Salad|Superfood Crunch': 'R-48119',
#  'GR|Salad|Thai Cucumber ': 'R-57013',
#  'GR|Salad|Warm Kale & Mushroom': 'R-62047',
#  'GR|Salad|Winter Root Veg': 'R-48998',
#  'GR|Sandwich|Classic BLT ': 'R-54377',
#  'GR|Sandwich|Classic Clubhouse': 'R-61852',
#  'GR|Sandwich|Classic Reuben ': 'R-57005',
#  'GR|Sandwich|Egg Salad ': 'R-32261',
#  'GR|Sandwich|Focaccia Caprese': 'R-57158',
#  'GR|Sandwich|Italian Hoagie': 'R-56941',
#  'GR|Sandwich|Meatball Marinara': 'R-60794',
#  'GR|Sandwich|Mediterranean Veg': 'R-57043',
#  'GR|Sandwich|Muffaletta ': 'R-56968',
#  'GR|Sandwich|Shrimp Remoulade': 'R-56924',
#  'GR|Sandwich|Turkey Pear & Brie': 'R-61854',
#  'GR|Signature green salad|SIDE': 'R-56900',
#  'GR|Signature greens|FULL': 'R-61833',
#  'GR|Smoothie|Blueberry Boost': 'R-51207',
#  'GR|Smoothie|Delish': 'R-51205',
#  'GR|Smoothie|Hawaiian Sun': 'R-51208',
#  'GR|Smoothie|Mango Bliss': 'R-43213',
#  'GR|Smoothie|Orange Zinger': 'R-51209',
#  'GR|Smoothie|Peachy Keen': 'R-54359',
#  'GR|Smoothie|Rise & Shine': 'R-51206',
#  'GR|Smoothie|Strwbry Cupid': 'R-49036',
#  'GR|Steel cut oat|Maple Apple': 'R-68039',
#  'GRAB CHEESE STRING ': 'R-25177',
#  'GRAB DESSERT SOY TOFU': 'R-22906',
#  'GRAB PEPPERONI CHEESE STICK': 'R-22903',
#  'GREEN SIDE SALAD': 'R-43302',
#  'GREEN2GO - CREDIT': 'R-63584',
#  'GREEN2GO - DEPOSIT': 'R-63583',
#  'GREEN2GO - REFUND': 'R-63592',
#  'GRILLED CHICKEN BREAST ONLY': 'R-63591',
#  'Grilled Foccacia': 'R-31046',
#  'GRL|Add Bacon|1 pc': 'R-22619',
#  'GRL|Add Bacon|2 pcs.': 'R-58255',
#  'GRL|Add On Cheese|1 slice': 'R-22618',
#  'GRL|Add on|Beef Burger Patty': 'R-34961',
#  'GRL|Add Prime Rib Burger Patty': 'R-51521',
#  'GRL|Bfast Potato Wedges|Side': 'R-38134',
#  'GRL|Chicken breast|add': 'R-46372',
#  'GRL|Chicken Burger|Katsu Featu': 'R-41319',
#  'GRL|Country Fried Portobello': 'R-61850',
#  'GRL|Crepe|Ham and Swiss': 'R-51146',
#  'GRL|Crepe|Mushroom Swiss': 'R-67745',
#  'GRL|Crepe|Nutella Banana': 'R-50569',
#  'GRL|Crepe|Rosemary Peach': 'R-50570',
#  'GRL|Feast Breakfast': 'R-46310',
#  'GRL|Grilled Eggplant|SIDE': 'R-56917',
#  'GRL|Grilled|Turkey & Swiss': 'R-67684',
#  'GRL|Monte Cristo Sandwich': 'R-52410',
#  'GRL|PANCAKES| BLUEBERRY (2PC)': 'R-65919',
#  'GRL|QUICHE| SPINACH & FETA': 'R-63590',
#  'GRL|Quiche|Bacon & Onion ': 'R-61880',
#  'GRL|Quiche|Ham & Cheese': 'R-51259',
#  'GRL|Quiche|Ham &Cheese': 'R-57035',
#  'GRL|Quiche|Mushroom & Red Pepp': 'R-67679',
#  'GRL|Quiche|Smoked Salmon': 'R-57034',
#  'GRL|Quiche|Spinach & Feta': 'R-51196',
#  'GRL|Quiche|Western': 'R-26809',
#  'GRL|Sandwich|Bacon & Egger': 'R-28230',
#  'GRL|Sandwich|Buffalo chicken': 'R-67844',
#  'GRL|Sandwich|Fried Egg ': 'R-54582',
#  'GRL|Sandwich|Pork Schnitzel': 'R-67184',
#  'GRL|Side Chicken Thigh|Grilled': 'R-22614',
#  'GRL|Side|Gravy': 'R-49580',
#  'GRL|SLIDER JERK PORK': 'R-54191',
#  'GRL|SLIDER|Jerk Pork 2 pc': 'R-54090',
#  'GRL|Smoked Salmon Bagel': 'R-49895',
#  'GRL|Strips|Crispy Chicken ': 'R-26785',
#  'HAND PAINTED SPRING GINGER COO': 'R-67027',
#  'HAND PIE': 'R-64340',
#  'HC| Bfast Sandwich|Turkey&Egg': 'R-44823',
#  "HC|B'fast Sand|Sausage & Egg": 'R-28232',
#  'HC|Beef sausage roll': 'R-71428',
#  'HC|Bfast Sandwich|B.E.T.C.': 'R-45077',
#  'HC|Bfast Sandwich|VEGAN': 'R-69443',
#  'HC|Bfast WrapMexi Egg': 'R-44828',
#  'HC|Ham & Cheese Croissant': 'R-71429',
#  'HC|Quiche|Asparagus & Asiago': 'R-71573',
#  'HC|Quiche|Broccoli & Cheddar': 'R-71574',
#  'HC|Quiche|Roasted Red Pepper': 'R-71575',
#  'HC|Samosa|Breakfast': 'R-26800',
#  'HC|Spanakopita': 'R-61988',
#  'HC|Spicy Jamaican Patty': 'R-64290',
#  'HM|Bread Pudding|STOLW': 'R-53974',
#  'HMS - BNS Succatash Sage': 'R-35128',
#  'HMS - Rst Maple Beets': 'R-29077',
#  'HMS - SWEET POTATO BLACK BEAN': 'R-38316',
#  'HS| Cowboy Beans|SIDE': 'R-56938',
#  'HS| Irish Colcannon': 'R-42764',
#  'HS| Steak & Mushroom': 'R-61792',
#  'HS|1/4 Chicken|PLATE': 'R-62034',
#  'HS|5 Spice Pork|BOWL': 'R-70784',
#  'HS|Adobo|Peppers & Onion|SIDE': 'R-62186',
#  'HS|B-nut Sqsh Chili w garnish': 'R-49183',
#  'HS|Bahn Mi|PORK BELLY ': 'R-62398',
#  'HS|Bahn Mi|VEGETARIAN ': 'R-62400',
#  'HS|Baked Potato Bar|RATIO': 'R-67285',
#  ...}

# %%
final2 = final.copy()
final2 = add_menu_names(final, OK_list)
final2.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.csv",
                  index=False)
final2.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/Data_Labelled_"+restaurant_name+"_with_name.xlsx",
                  index=False)

# %%
counts = create_final_counts(final2)
all_ghg_num = counts["GHG Label Counts"].sum()
all_num = counts["Combined Label Counts"].sum()
sum_row = pd.Series(data={"GHG Label Counts": all_ghg_num, "Combined Label Counts": all_num}, name="Sum")
# Out:
# 337 442 850

# %%
counts = counts.append(sum_row, ignore_index=False)
counts.to_csv("C:/Users/smvan/CFFS-S23/CFFS-22-23/data/final/2023_2024_CFFS_Outcomes/"+restaurant_name+"_Summary.csv", index=False)
counts_print = pd.concat([counts, sum_row], ignore_index=True)
counts


# THERE ARE 5 SUM ROWS BECUASE THERE ARE 5 EMISSION FACTORS THAT WE ARE LOOKING AT: GHG, nitrogen, stressed water, fresh water
# and land use
# Out:
# C:\Users\smvan\AppData\Local\Temp\ipykernel_10668\3944149530.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   counts = counts.append(sum_row, ignore_index=False)
#         GHG Label Counts  Combined Label Counts
# Red                  326                    337
# Yellow               331                    442
# Green                972                    850
# Sum                 1629                   1629

# %%
# THE BLUE BAR REPRESENTS THE SUM ROW WHICH IS THE TOTAL NUMBER OF RECIPES THAT HAVE BEEN ASSIGNED A LABEL
# EACH BAR REPRESENTS THE # OF RECIPES THAT WERE LABELLED WITH THAT SPECIFIC COLOUR

fig = create_visualizations(counts)
fig
